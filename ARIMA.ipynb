# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from pandas.plotting import lag_plot
from pandas import datetime
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error


def smape_kun(y_true, y_pred):
    return np.mean((np.abs(y_pred - y_true) * 200/ (np.abs(y_pred) +       np.abs(y_true))))

def classify(stock, last_val, data):
    result = [stock, 0, 0, 0, 0, 0]
    for i, day in enumerate(data):
        two_percent = last_val*0.02
        five_percent = last_val*0.05

        if(day >= last_val + five_percent):
            result[5] = 1
            result[4] = 1
        elif(day >= last_val + two_percent and day < last_val + five_percent):
            result[4] = 1
        elif(day <= last_val - two_percent and day > last_val - five_percent):
            result[2] = 1
        elif(day <= last_val - five_percent):
            result[1] = 1
            result[2] = 1
        
    if 1 not in result:
            result[3] = 1
        
    return result



#Main Algorithm  
stocks = ['VZ', 'T', 'WMT', 'MGM', 'GPS', 'GT', 'BBY', 'AFG', 'ERJ', 'MYE', 'ECPG', 'GCO', 'MPC', 'TRI', 'UFI']
stock_arrays = []
for stock in stocks:
    #data prep
    key = stock
    df = pd.read_csv(key+".csv").fillna(0)
    test_df = pd.read_csv(key+"_extra.csv").fillna(0)
    train_data = df.append(test_df[1:6])
    test_data = test_df[6:]
    train_ar = train_data['Close'].values
    test_ar = test_data['Close'].values
    history = [x for x in train_ar]
    predictions = list()
    test_result =  [str(key), 0,0,0,0,0]
    last_val = train_ar[len(train_ar) - 1]
    print("Last " + str(last_val))
    true_result = classify(stock,last_val, test_ar)

    
    #ARIMA
    for t in range(len(test_ar)):
    #for t in range(5):
        model = ARIMA(history, order=(5,1,0))
        model_fit = model.fit(disp=0)
        output = model_fit.forecast()
        yhat = output[0]
        predictions.append(yhat)
        obs = test_ar[t]
        history.append(obs)

    test_result = classify(stock, last_val, predictions)
    stock_arrays.append((test_result, true_result))
    error = mean_squared_error(test_ar, predictions)
    error2 = smape_kun(test_ar, predictions)
    

    plt.figure(figsize=(12,7))
    plt.plot(df['Close'], 'green', color='blue', label='Training Data')
    plt.plot(test_data.index, predictions, color='green', marker='o', linestyle='dashed', 
             label='Predicted Price')
    plt.plot(test_data.index, test_data['Close'], color='red', label='Actual Price')
    plt.title(key + ' Prices Prediction')
    plt.xlabel('Dates')
    plt.ylabel('Prices')
    #plt.xticks([1,2,3,4,5,6,7,8,9], [df['Date'][252], df['Date'][503], df['Date'][754], df['Date'][1005], df['Date'][1256], df['Date'][1507], df['Date'][1758], df['Date'][2009], df['Date'][2260]])
    plt.legend()


    plt.figure(figsize=(12,7))
    plot_pred = []
    for i in predictions:
        plot_pred.append(i[0])


    import matplotlib.dates as mdates
    import matplotlib.cbook as cbook
    print("RESULTS: " + key)
    print('Testing Mean Squared Error: %.3f' % error)
    print('Symmetric mean absolute percentage error: %.3f' % error2)
    print("last value: " +str(last_val))
    print()
    print("predicted stock prices: " + str(plot_pred))
    print("True stock prices: " + str(test_ar.tolist()))
    print("predicted array: " + str(test_result))
    print("True array: " + str(true_result))
    
   


    # Load a numpy structured array from yahoo csv data with fields date, open,
    # close, volume, adj_close from the mpl-data/example directory.  This array
    # stores the date as an np.datetime64 with a day unit ('D') in the 'date'
    # column.

    fig = plt.figure(figsize=(12,7))
    ax = plt.axes()


    print(test_data.index)

    ax.plot(test_data["Date"], test_data["Close"],color='red', label='Actual Price')
    ax.plot(test_data["Date"], plot_pred, color='blue', label='Predicted Price')
    ax.scatter(test_data["Date"], test_data["Close"])
    ax.scatter(test_data["Date"], plot_pred)
    plt.title('Prices Prediction')
    plt.xlabel('Dates')
    plt.ylabel(key + ' Prices')
    plt.legend()


    f = open("ARIMAresults.txt", "a")
    f.write("\n")
    f.write("pred: " + str(plot_pred) + "\n")
    f.write("true: " + str(test_ar.tolist()) + "\n")
    f.write("pred: " + str(test_result) + "\n")
    f.write("true: " + str(true_result) + "\n")
    f.close()


#for pair in stock_arrays:
# Out:
# <ipython-input-85-85be39cfe5eb>:5: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# Last 57.29999923706055
# RESULTS: VZ
# Testing Mean Squared Error: 0.343
# Symmetric mean absolute percentage error: 0.966
# last value: 57.29999923706055
#
# predicted stock prices: [57.32880349821087, 57.02085942186537, 56.431551213233334, 56.40355380046977, 57.309081963543356]
# True stock prices: [56.93999862670898, 56.31999969482422, 56.43000030517578, 57.31999969482422, 57.790000915527344]
# predicted array: ['VZ', 0, 0, 1, 0, 0]
# True array: ['VZ', 0, 0, 1, 0, 0]
# RangeIndex(start=6, stop=11, step=1)
# Last 31.399999618530273
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# RESULTS: T
# Testing Mean Squared Error: 0.109
# Symmetric mean absolute percentage error: 0.996
# last value: 31.399999618530273
#
# predicted stock prices: [31.4484613198977, 30.884629355015147, 30.66391819677199, 30.946793556257, 31.369586175998595]
# True stock prices: [30.90999984741211, 30.770000457763672, 30.959999084472656, 31.34000015258789, 31.40999984741211]
# predicted array: ['T', 0, 1, 0, 0, 0]
# True array: ['T', 0, 1, 0, 0, 0]
# RangeIndex(start=6, stop=11, step=1)
# Last 139.89999389648438
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# RESULTS: WMT
# Testing Mean Squared Error: 1.380
# Symmetric mean absolute percentage error: 0.646
# last value: 139.89999389648438
#
# predicted stock prices: [139.86019341651848, 138.1631081743557, 138.4155885905493, 138.00498877699826, 139.54731931226405]
# True stock prices: [137.91000366210938, 138.3800048828125, 137.88999938964844, 139.6300048828125, 139.91000366210938]
# predicted array: ['WMT', 0, 0, 1, 0, 0]
# True array: ['WMT', 0, 0, 1, 0, 0]
# RangeIndex(start=6, stop=11, step=1)
# Last 41.5099983215332
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# RESULTS: MGM
# Testing Mean Squared Error: 0.669
# Symmetric mean absolute percentage error: 1.846
# last value: 41.5099983215332
#
# predicted stock prices: [41.527611464067235, 41.50416016242413, 42.19501775682006, 42.06865970400352, 40.388023787068526]
# True stock prices: [41.47000122070313, 42.20000076293945, 42.02000045776367, 40.41999816894531, 40.72000122070313]
# predicted array: ['MGM', 0, 1, 0, 0, 0]
# True array: ['MGM', 0, 1, 0, 0, 0]
# RangeIndex(start=6, stop=11, step=1)
# Last 34.009998321533196
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# RESULTS: GPS
# Testing Mean Squared Error: 0.345
# Symmetric mean absolute percentage error: 1.388
# last value: 34.009998321533196
#
# predicted stock prices: [33.722297974573436, 33.53840690411521, 34.18464164928245, 34.22337461466523, 33.97906576269446]
# True stock prices: [33.470001220703125, 34.400001525878906, 34.259998321533196, 33.84999847412109, 33.09999847412109]
# predicted array: ['GPS', 0, 0, 1, 0, 0]
# True array: ['GPS', 0, 1, 0, 0, 0]
# RangeIndex(start=6, stop=11, step=1)
# Last 18.270000457763672
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# RESULTS: GT
# Testing Mean Squared Error: 0.111
# Symmetric mean absolute percentage error: 1.697
# last value: 18.270000457763672
#
# predicted stock prices: [18.303775613208558, 17.931024589216594, 17.950251451160145, 18.069624117367827, 17.739260136472343]
# True stock prices: [17.920000076293945, 17.950000762939453, 18.07999992370605, 17.739999771118164, 17.209999084472653]
# predicted array: ['GT', 0, 1, 0, 0, 0]
# True array: ['GT', 1, 1, 0, 0, 0]
# RangeIndex(start=6, stop=11, step=1)
# Last 117.73999786376952
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# RESULTS: BBY
# Testing Mean Squared Error: 1.892
# Symmetric mean absolute percentage error: 0.697
# last value: 117.73999786376952
#
# predicted stock prices: [117.81537020950071, 117.0535987097298, 118.40196831100936, 117.18283942545317, 118.37951747105924]
# True stock prices: [117.0199966430664, 118.3499984741211, 117.19000244140624, 118.29000091552734, 116.2699966430664]
# predicted array: ['BBY', 0, 0, 1, 0, 0]
# True array: ['BBY', 0, 0, 1, 0, 0]
# RangeIndex(start=6, stop=11, step=1)
# Last 123.77999877929688
# <ipython-input-85-85be39cfe5eb>:112: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=(12,7))
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# RESULTS: AFG
# Testing Mean Squared Error: 0.697
# Symmetric mean absolute percentage error: 0.448
# last value: 123.77999877929688
#
# predicted stock prices: [123.48511038966404, 123.0656864670931, 123.88120256610976, 122.77409905168346, 122.97940035279493]
# True stock prices: [122.75, 124.08000183105469, 122.55999755859376, 123.16999816894531, 122.86000061035156]
# predicted array: ['AFG', 0, 0, 1, 0, 0]
# True array: ['AFG', 0, 0, 1, 0, 0]
# RangeIndex(start=6, stop=11, step=1)
# Last 11.260000228881836
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# RESULTS: ERJ
# Testing Mean Squared Error: 0.088
# Symmetric mean absolute percentage error: 2.209
# last value: 11.260000228881836
#
# predicted stock prices: [11.260306040718435, 11.674156800752844, 11.585387024496837, 11.708300161878782, 11.29955180697442]
# True stock prices: [11.699999809265135, 11.59000015258789, 11.729999542236328, 11.3100004196167, 11.050000190734863]
# predicted array: ['ERJ', 0, 0, 0, 1, 0]
# True array: ['ERJ', 0, 0, 0, 1, 0]
# RangeIndex(start=6, stop=11, step=1)
# Last 21.780000686645508
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# RESULTS: MYE
# Testing Mean Squared Error: 0.037
# Symmetric mean absolute percentage error: 1.516
# last value: 21.780000686645508
#
# predicted stock prices: [21.746260437113445, 21.73240631753689, 21.954926783269347, 22.088305499202143, 22.37334633219587]
# True stock prices: [21.700000762939453, 21.959999084472656, 22.09000015258789, 22.3700008392334, 22.559999465942386]
# predicted array: ['MYE', 0, 0, 0, 1, 0]
# True array: ['MYE', 0, 0, 0, 1, 0]
# RangeIndex(start=6, stop=11, step=1)
# Last 38.72000122070313
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# RESULTS: ECPG
# Testing Mean Squared Error: 0.120
# Symmetric mean absolute percentage error: 0.652
# last value: 38.72000122070313
#
# predicted stock prices: [38.698131072336885, 38.96672978312396, 38.551719404835595, 39.04178319953282, 38.90695200406481]
# True stock prices: [38.97999954223633, 38.58000183105469, 38.97000122070313, 38.95000076293945, 39.34000015258789]
# predicted array: ['ECPG', 0, 0, 1, 0, 0]
# True array: ['ECPG', 0, 0, 1, 0, 0]
# RangeIndex(start=6, stop=11, step=1)
# Last 48.75
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# RESULTS: GCO
# Testing Mean Squared Error: 4.299
# Symmetric mean absolute percentage error: 4.064
# last value: 48.75
#
# predicted stock prices: [48.78320939558751, 47.065691411535475, 50.6406012527886, 52.15504315317256, 51.194933050423806]
# True stock prices: [47.09000015258789, 50.81000137329102, 52.27000045776367, 51.43000030517578, 50.0]
# predicted array: ['GCO', 0, 1, 0, 1, 1]
# True array: ['GCO', 0, 1, 0, 1, 1]
# RangeIndex(start=6, stop=11, step=1)
# Last 53.0
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# RESULTS: MPC
# Testing Mean Squared Error: 0.666
# Symmetric mean absolute percentage error: 2.547
# last value: 53.0
#
# predicted stock prices: [52.94803408716135, 53.24015925007158, 53.96681234084746, 55.43630271732103, 56.17070750587441]
# True stock prices: [53.27000045776367, 53.88999938964844, 55.43999862670898, 56.040000915527344, 55.6500015258789]
# predicted array: ['MPC', 0, 0, 0, 1, 1]
# True array: ['MPC', 0, 0, 0, 1, 1]
# RangeIndex(start=6, stop=11, step=1)
# Last 91.87999725341795
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# RESULTS: TRI
# Testing Mean Squared Error: 0.322
# Symmetric mean absolute percentage error: 0.543
# last value: 91.87999725341795
#
# predicted stock prices: [91.89694368646477, 92.0455276510654, 92.72733486372896, 92.34969941916724, 93.13039333605946]
# True stock prices: [92.04000091552734, 92.7699966430664, 92.2300033569336, 93.1500015258789, 92.70999908447266]
# predicted array: ['TRI', 0, 0, 1, 0, 0]
# True array: ['TRI', 0, 0, 1, 0, 0]
# RangeIndex(start=6, stop=11, step=1)
# Last 27.82999992370605
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# RESULTS: UFI
# Testing Mean Squared Error: 1.105
# Symmetric mean absolute percentage error: 2.895
# last value: 27.82999992370605
#
# predicted stock prices: [27.784977919910215, 27.603087401246306, 27.83141844628134, 28.713227627098384, 26.646499708885507]
# True stock prices: [27.53000068664551, 27.90999984741211, 28.70000076293945, 26.60000038146973, 27.03000068664551]
# predicted array: ['UFI', 0, 1, 0, 1, 0]
# True array: ['UFI', 0, 1, 0, 1, 0]
# RangeIndex(start=6, stop=11, step=1)
